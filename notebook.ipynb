# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("paultimothymooney/recipenlg")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 643M/643M [00:18<00:00, 35.5MB/s]
# Extracting model files...
# Path to dataset files: /Users/alejandro-germosen/.cache/kagglehub/datasets/paultimothymooney/recipenlg/versions/1

# %%
import pandas as pd

# Load the dataset
ds = pd.read_csv('/Users/alejandro-germosen/.cache/kagglehub/datasets/paultimothymooney/recipenlg/versions/1/RecipeNLG_dataset.csv')   
ds.head()
# Out:
#    Unnamed: 0                  title  \
# 0           0    No-Bake Nut Cookies
# 1           1  Jewell Ball'S Chicken
# 2           2            Creamy Corn
# 3           3          Chicken Funny
# 4           4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# ...

# %%
ds.head(30)
# Out:
#     Unnamed: 0                                              title  \
# 0            0                                No-Bake Nut Cookies
# 1            1                              Jewell Ball'S Chicken
# 2            2                                        Creamy Corn
# 3            3                                      Chicken Funny
# 4            4                               Reeses Cups(Candy)
# 5            5                           Cheeseburger Potato Soup
# 6            6                                Rhubarb Coffee Cake
# 7            7                                     Scalloped Corn
# 8            8                               Nolan'S Pepper Steak
# 9            9                                    Millionaire Pie
# 10          10                              Double Cherry Delight
# 11          11                                      Buckeye Candy
# 12          12                               Quick Barbecue Wings
# ...

# %%
ds['source'].value_counts()
# Out:
# source
# Gathered     1643098
# Recipes1M     588044
# Name: count, dtype: int64

# %%
len(ds)
# Out:
# 2231142

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("bwandowando/spotify-songs-with-attributes-and-lyrics")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 894M/894M [00:32<00:00, 28.7MB/s]
# Extracting model files...
# Path to dataset files: /Users/alejandro-germosen/.cache/kagglehub/datasets/bwandowando/spotify-songs-with-attributes-and-lyrics/versions/18

# %%
lyrics_ds = pd.read_csv('/Users/alejandro-germosen/.cache/kagglehub/datasets/bwandowando/spotify-songs-with-attributes-and-lyrics/versions/18/songs_with_attributes_and_lyrics.csv/songs_with_attributes_and_lyrics.csv')
lyrics_ds.head()
# Out:
#                        id             name  \
# 0  0Prct5TDjAnEgIqbxcldY9                !
# 1  2ASl4wirkeYm3OWZxXKYuq               !!
# 2  69lcggVPmOr9cvPx9kLiiN  !!! - Interlude
# 3  4U7dlZjg1s9pjdppqZy0fm   !!De Repente!!
# 4  4v1IBp3Y3rpkWmWzIlkYju   !!De Repente!!
#
#                                album_name       artists  danceability  energy  \
# 0                              UNDEN!ABLE  ['HELLYEAH']         0.415  0.6050
# 1                                     NaN       Yxngxr1         0.788  0.6480
# 2                       Where I Belong EP    ['Glowie']         0.000  0.0354
# 3  Un Palo Al Agua (20 Grandes Canciones)   ['Rosendo']         0.657  0.8820
# 4                          Fuera De Lugar   ['Rosendo']         0.659  0.8930
#
#   key  loudness mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   7   -11.157    1       0.0575       0.00116          0.838000    0.4710
# 1   7    -9.135    0       0.3150       0.90000          0.000000    0.1760
# ...

# %%
# Conver all values in the column name from NaN to 'Unknown'
lyrics_ds['name'] = lyrics_ds['name'].fillna('Unknown')

# %%
# Filter by name 
lyrics_ds[lyrics_ds['name'].str.contains('smooth criminal', case=False)].head()
# Out:
#                             id                       name album_name  \
# 70078   62l3NSQPUxvcwwzKUmysrE  Bad Man (Smooth Criminal)        NaN
# 705801  1VM7U86h178lOgV52BNzlJ            Smooth Criminal        NaN
# 705802  2T3blUc9Jnui2a0ZhuNOag            Smooth Criminal  Anthology
# 705803  5vpYVynwQg7L7jgnvEp8xM            Smooth Criminal        NaN
# 705804  5z6xHjCZr7a7AIcy8sPBKy            Smooth Criminal  Anthology
#
#                     artists  danceability  energy  key  loudness mode  \
# 70078            ['Polo G']         0.882   0.662  0.0    -6.382  1.0
# 705801  ['Various Artists']         0.732   0.891  9.0    -5.859  0.0
# 705802       Alien Ant Farm         0.653   0.966    9    -4.236    0
# 705803       Alien Ant Farm         0.597   0.966    9    -4.092    0
# 705804       Alien Ant Farm         0.653   0.964    9    -4.261    0
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
lyrics_ds.columns

# list the columns separated by comma "first, second, third"
columns = ', '.join(lyrics_ds.columns)
columns
# Out:
# 'id, name, album_name, artists, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, lyrics'

# %%
lyrics_ds[lyrics_ds['id'] == '4jFl904O3cx2wNMMIXAwlw']['lyrics'].values[0]
# Out:
# "As he came into the window\n It was the sound of a crescendo\n He came into her apartment\n He left the bloodstains on the carpet\n She ran underneath the table\n He could see she was unable\n So she ran into the bedroom\n She was struck down\n It was her doom\n Annie, are you okay?\n So, Annie, are you okay?\n Are you okay, Annie?\n Annie, are you okay?\n So, Annie, are you okay?\n Are you okay, Annie?\n Annie, are you okay?\n So, Annie, are you okay?\n Are you okay, Annie?\n Annie, are you okay?\n So, Annie, are you okay?\n Are you okay, Annie?\n Annie, are you okay?\n Will you tell us that you're okay?\n There's a sign in the window\n That he struck you - a crescendo, Annie\n He came into your apartment\n He left the bloodstains on the carpet\n Then you ran into the bedroom\n You were struck down\n It was your doom\n Annie, are you okay?\n So, Annie, are you okay?\n Are you okay, Annie?\n You've been hit by\n You've been hit by a smooth criminal\n Ow!\n ♪\n (Okay, I want everybod
# ...

# %%
lyrics_ds[lyrics_ds['id'] == '1VM7U86h178lOgV52BNzlJ']['lyrics'].values[0]
# Out:
# "Don't stop 'till you get it now,\n ooh, don't stop\n Don't stop 'till you get it now\n It's thriller!\n Don't stop 'till you get it now\n It's thriller!\n It's thriller!\n As he came into the window\n It was the sound of a crescendo\n He came into her apartment\n He left the bloodstains on the carpet\n She ran underneath the table\n He could see she was unable\n So she ran into the bedroom\n She was struck down, it was her doom\n Annie, is you OK?\n So, Annie, is you OK?\n Are you OK, Annie?\n Annie, is you OK?\n So, Annie, is you OK?\n Are you OK, Annie?\n Annie, is you OK?\n So, Annie, is you OK?\n Are you OK, Annie?\n Annie, is you OK?\n So, Annie, are you OK,?\n Are you OK, Annie?\n (Annie, are you OK?)\n (will you tell us that you're OK)\n (there's a sign up in the window)\n (that he struck you a crescendo Annie)\n (he came into your apartment)\n (he left the bloodstains on the carpet)\n (so you ran into the bedroom)\n (you were struck down)\n (it was your doom)\n Annie, are yo
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tharunprabu/songs-data-with-full-lyrics")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 37.4k/37.4k [00:00<00:00, 2.73MB/s]
# Extracting model files...
# Path to dataset files: /Users/alejandro-germosen/.cache/kagglehub/datasets/tharunprabu/songs-data-with-full-lyrics/versions/2

# %%
lyrics_ds_2 = pd.read_csv('/Users/alejandro-germosen/.cache/kagglehub/datasets/tharunprabu/songs-data-with-full-lyrics/versions/2/songs_with_lyrics.csv')
lyrics_ds_2.head()
# Out:
#                 Song Title      Artist                 Album  Release Year  \
# 0        Bohemian Rhapsody       Queen  A Night at the Opera          1975
# 1             Shape of You  Ed Sheeran            ÷ (Divide)          2017
# 2      Rolling in the Deep       Adele                    21          2010
# 3         Hotel California      Eagles      Hotel California          1976
# 4  Smells Like Teen Spirit     Nirvana             Nevermind          1991
#
#       Genre                                             Lyrics
# 0      Rock  Is this the real life? Is this just fantasy?\n...
# 1       Pop  The club isn't the best place to find a lover\...
# 2  Pop Soul  There's a fire starting in my heart\nReaching ...
# 3      Rock  On a dark desert highway\nCool wind in my hair...
# 4    Grunge  Load up on guns, bring your friends\nIt's fun ...

# %%
len(lyrics_ds_2)
# Out:
# 69
